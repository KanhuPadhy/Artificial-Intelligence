# %% [markdown]
# <a href="https://colab.research.google.com/github/KanhuPadhy/Artificial-Intelligence/blob/main/Untitled122.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Shark Species Detection Using CNN**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
from PIL import Image            # PIL  - Python Image Library

# %%
img1=Image.open("/content/drive/MyDrive/sharks images/Sharks/basking/00000004.jpg")
img1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x667>

# %%
img1.size
# Out:
# (1000, 667)

# %%
img2=Image.open("/content/drive/MyDrive/sharks images/Sharks/basking/00000001.jpg")
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1920x1080>

# %%
img2.size
# Out:
# (1920, 1080)

# %%
# Steps of Image processing
#Resizing the Image
